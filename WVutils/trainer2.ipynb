# %%
import os
import sys
sys.path.append("..")
import keras
import keras.backend as K
from WVutils.data import *
from keras.layers import *
from keras.models import *
from keras.optimizers import *
from keras.callbacks import *
from datautils.other import *
from models.model import *
# Out:
# /home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Building prefix dict from the default dictionary ...
# 2018-07-30 22:25:00 PM:DEBUG:Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# 2018-07-30 22:25:00 PM:DEBUG:Loading model from cache /tmp/jieba.cache
# Loading model cost 0.757 seconds.
# 2018-07-30 22:25:01 PM:DEBUG:Loading model cost 0.757 seconds.
# Prefix dict has been built succesfully.
# 2018-07-30 22:25:01 PM:DEBUG:Prefix dict has been built succesfully.

# %%
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
train = pd.read_csv(Config.cache_path + 'trainset.csv', sep='\t')
val = pd.read_csv(Config.cache_path + 'valset.csv', sep='\t')

# %%
from keras.utils import to_categorical
val_label = to_categorical(val.label)

# %%
from datautils.pre import *
from WVutils.config import *

# %%
batch_size=64
model_name='textcnn_noTD'
train_batch_generator = word_cnn_train_batch_generator
print('Loading data')
# Out:
# Loading data

# %%
val_word_seq = pickle.load(open(Config.cache_path + 'val_cnn_seq.pkl', 'rb'))
word_embed_weight = np.load(Config.word_embed_weight_path)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[235146,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: embedding_1/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=5631299, _device="/job:localhost/replica:0/task:0/device:GPU:0"](embedding_1/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-7-c274b0733ea9> in <module>()
#       1 val_word_seq = pickle.load(open(Config.cache_path + 'val_cnn_seq.pkl', 'rb'))
#       2 word_embed_weight = np.load(Config.word_embed_weight_path)
# ----> 3 model=get_textcnn_no_TD(Config.word_seq_maxlen, word_embed_weight)
#       4 model.summary()
#
# ~/pythonenv/Notebook/nlp/360_extension/models/model.py in get_textcnn_no_TD(seq_length, embed_weight)
#     149     content = Input(shape=(seq_length, ), dtype='int32')
#     150     embedding = Embedding(input_dim=embed_weight.shape[0], weights=[embed_weight], output_dim=embed_weight.shape[1], trainable=False)
# --> 151     trans_content = Activation(activation='relu')(BatchNormalization()(embedding(content)))
#     152     feat = convs_block(trans_content)
#     153     dropfeat = Dropout(0.2)(feat)
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     597                 # Load weights that were specified at layer instantiation.
#     598                 if self._initial_weights is not None:
# --> 599                     self.set_weights(self._initial_weights)
#     600
#     601             # Raise exceptions in case the input is not compatible
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in set_weights(self, weights)
#    1211             return
#    1212         weight_value_tuples = []
# -> 1213         param_values = K.batch_get_value(params)
#    1214         for pv, p, w in zip(param_values, params, weights):
#    1215             if pv.shape != w.shape:
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in batch_get_value(ops)
#    2325     """
#    2326     if ops:
# -> 2327         return get_session().run(ops)
#    2328     else:
#    2329         return []
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     198                     v._keras_initialized = True
#     199                 if uninitialized_vars:
# --> 200                     session.run(tf.variables_initializer(uninitialized_vars))
#     201     # hack for list_devices() function.
#     202     # list_devices() function is not available under tensorflow r1.3.
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[235146,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: embedding_1/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=5631299, _device="/job:localhost/replica:0/task:0/device:GPU:0"](embedding_1/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'embedding_1/random_uniform/RandomUniform', defined at:
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-c274b0733ea9>", line 3, in <module>
#     model=get_textcnn_no_TD(Config.word_seq_maxlen, word_embed_weight)
#   File "../models/model.py", line 151, in get_textcnn_no_TD
#     trans_content = Activation(activation='relu')(BatchNormalization()(embedding(content)))
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py", line 592, in __call__
#     self.build(input_shapes[0])
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/layers/embeddings.py", line 105, in build
#     dtype=self.dtype)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py", line 413, in add_weight
#     weight = K.variable(initializer(shape),
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/initializers.py", line 112, in __call__
#     dtype=dtype, seed=self.seed)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 3838, in random_uniform
#     dtype=dtype, seed=seed)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/random_ops.py", line 242, in random_uniform
#     rnd = gen_random_ops.random_uniform(shape, dtype, seed=seed1, seed2=seed2)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_random_ops.py", line 674, in random_uniform
#     name=name)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[235146,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: embedding_1/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=5631299, _device="/job:localhost/replica:0/task:0/device:GPU:0"](embedding_1/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
model=get_textcnn_no_TD(Config.word_seq_maxlen, word_embed_weight)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[235146,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: embedding_2/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=8379352, _device="/job:localhost/replica:0/task:0/device:GPU:0"](embedding_2/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-8-5abe7008963e> in <module>()
# ----> 1 model=get_textcnn_no_TD(Config.word_seq_maxlen, word_embed_weight)
#       2 model.summary()
#
# ~/pythonenv/Notebook/nlp/360_extension/models/model.py in get_textcnn_no_TD(seq_length, embed_weight)
#     149     content = Input(shape=(seq_length, ), dtype='int32')
#     150     embedding = Embedding(input_dim=embed_weight.shape[0], weights=[embed_weight], output_dim=embed_weight.shape[1], trainable=False)
# --> 151     trans_content = Activation(activation='relu')(BatchNormalization()(embedding(content)))
#     152     feat = convs_block(trans_content)
#     153     dropfeat = Dropout(0.2)(feat)
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     597                 # Load weights that were specified at layer instantiation.
#     598                 if self._initial_weights is not None:
# --> 599                     self.set_weights(self._initial_weights)
#     600
#     601             # Raise exceptions in case the input is not compatible
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in set_weights(self, weights)
#    1211             return
#    1212         weight_value_tuples = []
# -> 1213         param_values = K.batch_get_value(params)
#    1214         for pv, p, w in zip(param_values, params, weights):
#    1215             if pv.shape != w.shape:
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in batch_get_value(ops)
#    2325     """
#    2326     if ops:
# -> 2327         return get_session().run(ops)
#    2328     else:
#    2329         return []
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     198                     v._keras_initialized = True
#     199                 if uninitialized_vars:
# --> 200                     session.run(tf.variables_initializer(uninitialized_vars))
#     201     # hack for list_devices() function.
#     202     # list_devices() function is not available under tensorflow r1.3.
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[235146,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: embedding_2/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=8379352, _device="/job:localhost/replica:0/task:0/device:GPU:0"](embedding_2/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'embedding_2/random_uniform/RandomUniform', defined at:
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-5abe7008963e>", line 1, in <module>
#     model=get_textcnn_no_TD(Config.word_seq_maxlen, word_embed_weight)
#   File "../models/model.py", line 151, in get_textcnn_no_TD
#     trans_content = Activation(activation='relu')(BatchNormalization()(embedding(content)))
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py", line 592, in __call__
#     self.build(input_shapes[0])
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/layers/embeddings.py", line 105, in build
#     dtype=self.dtype)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py", line 413, in add_weight
#     weight = K.variable(initializer(shape),
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/initializers.py", line 112, in __call__
#     dtype=dtype, seed=self.seed)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 3838, in random_uniform
#     dtype=dtype, seed=seed)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/random_ops.py", line 242, in random_uniform
#     rnd = gen_random_ops.random_uniform(shape, dtype, seed=seed1, seed2=seed2)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_random_ops.py", line 674, in random_uniform
#     name=name)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "/home/deep/pythonenv/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[235146,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: embedding_2/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=8379352, _device="/job:localhost/replica:0/task:0/device:GPU:0"](embedding_2/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
